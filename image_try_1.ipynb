# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\neuer\E FWG VBS VXDF BSD V WSRGW.jpeg')
img.shape
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_12452\1902795959.py:1: SyntaxWarning: invalid escape sequence '\@'
#   img = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\neuer\E FWG VBS VXDF BSD V WSRGW.jpeg')
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_12452\1902795959.py:1: SyntaxWarning: invalid escape sequence '\@'
#   img = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\neuer\E FWG VBS VXDF BSD V WSRGW.jpeg')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 img = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\neuer\E FWG VBS VXDF BSD V WSRGW.jpeg')
# ----> 2 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 plt.imshow(img)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\pyplot.py:3343, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3322 @_copy_docstring_and_deprecators(Axes.imshow)
#    3323 def imshow(
#    3324     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3341     **kwargs,
#    3342 ) -> AxesImage:
# -> 3343     __ret = gca().imshow(
#    3344         X,
#    3345         cmap=cmap,
#    3346         norm=norm,
#    3347         aspect=aspect,
#    3348         interpolation=interpolation,
#    3349         alpha=alpha,
#    3350         vmin=vmin,
#    3351         vmax=vmax,
# ...

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1038, 1600)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[670, 285, 671, 671]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (670, 285, 671, 671)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
for (x, y, w, h) in faces:
        face_img=cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = face_img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\9e30af3e8d.jpg')
plt.imshow(original_image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_17472\256380088.py:1: SyntaxWarning: invalid escape sequence '\@'
#   original_image = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\9e30af3e8d.jpg')

# %%
cropped_image = get_cropped_image_if_2_eyes('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\9e30af3e8d.jpg')
plt.imshow(cropped_image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_17472\426755809.py:1: SyntaxWarning: invalid escape sequence '\@'
#   cropped_image = get_cropped_image_if_2_eyes('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\9e30af3e8d.jpg')

# %%
org_image_obstructed = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\MariaS-W1200.jpg.gallery.jpg')
plt.imshow(org_image_obstructed)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_17472\3008279306.py:1: SyntaxWarning: invalid escape sequence '\@'
#   org_image_obstructed = cv2.imread('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\MariaS-W1200.jpg.gallery.jpg')

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\MariaS-W1200.jpg.gallery.jpg')
cropped_image_no_2_eyes
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# <>:1: SyntaxWarning: invalid escape sequence '\@'
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_17472\271258880.py:1: SyntaxWarning: invalid escape sequence '\@'
#   cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('D:\@Masrafe\Coding\Git Hub code\ml project\IMAGE_PROJECT\image_dataset\MariaS-W1200.jpg.gallery.jpg')

# %%
path_to_data = "./image_dataset/"
path_to_cr_data = "./image_dataset/cropped/"
